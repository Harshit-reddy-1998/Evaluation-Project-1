# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('baseball.csv')
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# We have 30 rows and 17 columns.

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# Here, we have all the int data types in all the columns except ERA (Earned run average) column.

# %% [markdown]
# # To check missing values

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# We have no missing values in any of the columns.

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Summary Statistics

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# There is a large difference in the 75th percentile and max in SO (Shutouts) column.

# %%
dfcorr=df.corr()
dfcorr
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
plt.figure(figsize=(15,5))
sns.heatmap(dfcorr,cmap='rocket_r',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The three columns RA (Runs Allowed), ER (Earned Runs) and ERA (Earned runs average) are highly negatively correlated.

# %% [markdown]
# # EDA

# %%
k=['R','AB','H','2B','3B','HR']
j=1
plt.figure(figsize=(10,5))
for i in k:
    plt.subplot(2,3,j)
    sns.distplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %% [markdown]
# There is some skewness present in R (Runs) column where as data is distributed normally in the other columns.

# %%
k=['BB','SO','SB','RA','ER','ERA']
j=1
plt.figure(figsize=(10,5))
for i in k:
    plt.subplot(2,3,j)
    sns.distplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %% [markdown]
# Datas are normally distributed in all the columns.

# %%
k=['CG','SHO','SV','E']
j=1
plt.figure(figsize=(10,5))
for i in k:
    plt.subplot(2,2,j)
    sns.distplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %% [markdown]
# The datas are not distributed normally in any of the columns as there is some skewness present in all the columns.

# %%
k=['R','AB','H','2B','3B','HR']
j=1
plt.figure(figsize=(10,5))
for i in k:
    plt.subplot(2,3,j)
    sns.boxplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %% [markdown]
# There is outlier present in R (Runs) column and rest of the columns, there are no outliers.

# %%
k=['BB','SO','SB','RA','ER','ERA']
j=1
plt.figure(figsize=(10,5))
for i in k:
    plt.subplot(2,3,j)
    sns.boxplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %% [markdown]
# There is outlier present in ERA (Earned Runs Average) column and rest of the columns, there are no outliers.

# %%
k=['CG','SHO','SV','E']
j=1
plt.figure(figsize=(10,5))
for i in k:
    plt.subplot(2,2,j)
    sns.boxplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %% [markdown]
# There are some outliers present in these columns except CG column.

# %%
y=df[['W']]

# %%
for i in df.columns:
    print('The unique values in {} are {}'.format(i,df[i].nunique()))
# Out:
# The unique values in W are 24
# The unique values in R are 28
# The unique values in AB are 29
# The unique values in H are 29
# The unique values in 2B are 22
# The unique values in 3B are 23
# The unique values in HR are 27
# The unique values in BB are 29
# The unique values in SO are 29
# The unique values in SB are 27
# The unique values in RA are 30
# The unique values in ER are 30
# The unique values in ERA are 30
# The unique values in CG are 9
# The unique values in SHO are 12
# The unique values in SV are 20
# The unique values in E are 21

# %%
df.drop('W',axis=1,inplace=True)

# %%
df.skew()
# Out:
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# There is some skewness present in some of the columns. Lets remove that by applying some transforms.

# %%
df_new=df.copy(deep=True)

# %%
for col in df_new.columns:
    percentiles = df_new[col].quantile([0.01, 0.99]).values
    df_new[col][df_new[col] <= percentiles[0]] = percentiles[0]
    df_new[col][df_new[col] >= percentiles[1]] = percentiles[1]

# %%
df_new.skew()
# Out:
# R      0.819139
# AB     0.213089
# H      0.662031
# 2B    -0.217119
# 3B     0.156165
# HR     0.587084
# BB     0.164091
# SO    -0.164525
# SB     0.498184
# RA     0.114676
# ER     0.063043
# ERA    0.020576
# CG     0.541537
# SHO    0.565790
# SV     0.718597
# E      0.879296
# dtype: float64

# %%
df_new['R']=np.log(df_new['R'])
sns.distplot(df_new['R'])
# Out:
# <AxesSubplot:xlabel='R', ylabel='Density'>

# %%
df_new['H']=np.sqrt(df_new['H'])
sns.distplot(df_new['H'])
# Out:
# <AxesSubplot:xlabel='H', ylabel='Density'>

# %%
df_new['HR']=np.log(df_new['HR'])
sns.distplot(df_new['HR'])
# Out:
# <AxesSubplot:xlabel='HR', ylabel='Density'>

# %%
df_new['SHO']=np.sqrt(df_new['SHO'])
sns.distplot(df_new['SHO'])
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='Density'>

# %%
df_new['SV']=np.cbrt(df_new['SV'])
sns.distplot(df_new['SV'])
# Out:
# <AxesSubplot:xlabel='SV', ylabel='Density'>

# %%
df_new['E']=np.log(df_new['E'])
sns.distplot(df_new['E'])
# Out:
# <AxesSubplot:xlabel='E', ylabel='Density'>

# %%
df_new.skew()
# Out:
# R      0.500724
# AB     0.213089
# H      0.642332
# 2B    -0.217119
# 3B     0.156165
# HR     0.135312
# BB     0.164091
# SO    -0.164525
# SB     0.498184
# RA     0.114676
# ER     0.063043
# ERA    0.020576
# CG     0.541537
# SHO   -0.061761
# SV     0.436613
# E      0.628019
# dtype: float64

# %% [markdown]
# After applying the transforms, skewness has been removed except in one or two columns.

# %%
k=['R','AB','H','2B','3B','HR']
j=1
plt.figure(figsize=(10,5))
for i in k:
    plt.subplot(2,3,j)
    sns.distplot(df_new[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %% [markdown]
# Datas are distributed normally in all the columns.

# %%
k=['BB','SO','SB','RA','ER','ERA']
j=1
plt.figure(figsize=(10,5))
for i in k:
    plt.subplot(2,3,j)
    sns.distplot(df_new[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %% [markdown]
# Datas are distributed normally in all the columns.

# %%
k=['CG','SHO','SV','E']
j=1
plt.figure(figsize=(10,5))
for i in k:
    plt.subplot(2,2,j)
    sns.distplot(df_new[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %% [markdown]
# Datas are distributed normally in all the columns.

# %%
k=['R','AB','H','2B','3B','HR']
j=1
plt.figure(figsize=(10,5))
for i in k:
    plt.subplot(2,3,j)
    sns.boxplot(df_new[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %% [markdown]
# There are no outliers present in these columns.

# %%
k=['BB','SO','SB','RA','ER','ERA']
j=1
plt.figure(figsize=(10,5))
for i in k:
    plt.subplot(2,3,j)
    sns.boxplot(df_new[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %% [markdown]
# There are no outliers present in these columns.

# %%
k=['CG','SHO','SV','E']
j=1
plt.figure(figsize=(10,5))
for i in k:
    plt.subplot(2,2,j)
    sns.boxplot(df_new[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %% [markdown]
# Thsere are some outliers present in the two columns.

# %%
df_new
# Out:
#            R       AB          H      2B     3B        HR      BB       SO  \
# 0   6.584791  5575.00  38.691084  300.00  42.00  4.934474  383.00  1011.86
# 1   6.545350  5467.00  36.728735  277.00  44.00  5.049856  439.00  1264.00
# 2   6.505784  5439.00  37.349699  303.00  29.00  4.948760  533.00  1157.00
# 3   6.432940  5533.00  37.161808  260.00  27.00  4.912655  404.00  1231.00
# 4   6.535241  5605.00  38.855888  289.00  49.00  5.017280  455.00  1259.00
# 5   6.750130  5509.00  38.470768  306.55  17.00  5.444234  569.13  1151.00
# 6   6.638568  5567.00  37.376463  272.00  19.00  5.356586  554.00  1227.00
# 7   6.569481  5485.00  37.013511  246.00  20.00  5.379897  418.00  1331.00
# 8   6.467699  5485.00  37.188708  278.00  32.00  5.117994  436.00  1310.00
# 9   6.617403  5640.00  38.665230  294.00  33.00  5.081404  478.00  1148.00
# 10  6.621406  5511.00  37.669616  279.00  32.00  5.147494  503.00  1233.00
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scale=scaler.fit_transform(df_new)
scale
# Out:
# array([[ 7.26119621e-01,  8.53573157e-01,  1.67099060e+00,
#          1.43795089e+00,  1.04423479e+00, -7.92448936e-01,
#         -1.54071840e+00, -2.47400647e+00,  9.18278024e-01,
#         -6.92653250e-01, -5.22846534e-01, -5.21280731e-01,
#         -5.45889641e-01, -7.81873120e-01,  1.64763258e+00,
#         -4.29499709e-01],
#        [ 2.03173544e-01, -7.21957956e-01, -9.81875450e-01,
#          1.27995893e-01,  1.24012676e+00, -1.70082058e-01,
#         -5.39187352e-01,  1.64530995e-01, -6.08318968e-01,
#          1.66398884e-01,  2.56805329e-01,  2.64476711e-01,
#         -5.45889641e-01,  2.59566641e-01,  3.09677528e-01,
#         -5.95572421e-01],
#        [-3.21414863e-01, -1.13042898e+00, -1.42405539e-01,
#          1.60881459e+00, -2.29063009e-01, -7.15390982e-01,
#          1.14195404e+00, -9.55178327e-01,  1.10079616e-01,
#         -7.07213456e-01, -7.77732720e-01, -6.59943809e-01,
#          2.45115152e+00, -2.34918307e-01, -6.59918696e-01,
#         -1.20887283e+00],
# ...

# %%
df_new=pd.DataFrame(scale,columns=['R','AB','H','2B','3B','HR','BB','SO','SB','RA','ER','ERA','CG','SHO','SV','E'])
df_new
# Out:
#            R        AB         H        2B        3B        HR        BB  \
# 0   0.726120  0.853573  1.670991  1.437951  1.044235 -0.792449 -1.540718
# 1   0.203174 -0.721958 -0.981875  0.127996  1.240127 -0.170082 -0.539187
# 2  -0.321415 -1.130429 -0.142406  1.608815 -0.229063 -0.715391  1.141954
# 3  -1.287231  0.240867 -0.396411 -0.840232 -0.424955 -0.910140 -1.165144
# 4   0.069149  1.291221  1.893785  0.811451  1.729857 -0.345797 -0.253036
# 5   2.918298 -0.109251  1.373149  1.811003 -1.404415  1.957180  1.788120
# 6   1.439125  0.736867 -0.106223 -0.156777 -1.208523  1.484410  1.517528
# 7   0.523129 -0.459369 -0.596892 -1.637596 -1.110577  1.610149 -0.914761
# 8  -0.826377 -0.459369 -0.360046  0.184950  0.064775  0.197451 -0.592841
# 9   1.158507  1.801809  1.636039  1.096224  0.162721  0.000089  0.158307
# 10  1.211577 -0.080075  0.290086  0.241905  0.064775  0.356576  0.605420
# 11  0.817370 -0.838664 -0.724890  0.184950 -0.522901  1.923981  0.301383
# ...

# %%
df_new['W']=y['W']
df_new
# Out:
#            R        AB         H        2B        3B        HR        BB  \
# 0   0.726120  0.853573  1.670991  1.437951  1.044235 -0.792449 -1.540718
# 1   0.203174 -0.721958 -0.981875  0.127996  1.240127 -0.170082 -0.539187
# 2  -0.321415 -1.130429 -0.142406  1.608815 -0.229063 -0.715391  1.141954
# 3  -1.287231  0.240867 -0.396411 -0.840232 -0.424955 -0.910140 -1.165144
# 4   0.069149  1.291221  1.893785  0.811451  1.729857 -0.345797 -0.253036
# 5   2.918298 -0.109251  1.373149  1.811003 -1.404415  1.957180  1.788120
# 6   1.439125  0.736867 -0.106223 -0.156777 -1.208523  1.484410  1.517528
# 7   0.523129 -0.459369 -0.596892 -1.637596 -1.110577  1.610149 -0.914761
# 8  -0.826377 -0.459369 -0.360046  0.184950  0.064775  0.197451 -0.592841
# 9   1.158507  1.801809  1.636039  1.096224  0.162721  0.000089  0.158307
# 10  1.211577 -0.080075  0.290086  0.241905  0.064775  0.356576  0.605420
# 11  0.817370 -0.838664 -0.724890  0.184950 -0.522901  1.923981  0.301383
# ...

# %%
sns.pairplot(df_new)

# %%
sns.histplot(df_new['AB'])
# Out:
# <AxesSubplot:xlabel='AB', ylabel='Count'>

# %% [markdown]
# The plots are normally distributed as there is no skewness.

# %%
sns.histplot(df_new['2B'])
# Out:
# <AxesSubplot:xlabel='2B', ylabel='Count'>

# %% [markdown]
# The plots are normally distributed as there is no skewness.

# %%
sns.histplot(df_new['3B'])
# Out:
# <AxesSubplot:xlabel='3B', ylabel='Count'>

# %% [markdown]
# The plots are normally distributed as there is no skewness.

# %%
sns.histplot(df_new['HR'])
# Out:
# <AxesSubplot:xlabel='HR', ylabel='Count'>

# %% [markdown]
# The plots are normally distributed as there is no skewness.

# %%
sns.histplot(df_new['ER'])
# Out:
# <AxesSubplot:xlabel='ER', ylabel='Count'>

# %% [markdown]
# The plots are normally distributed as there is no skewness.

# %%
df1=df_new
df1
# Out:
#            R        AB         H        2B        3B        HR        BB  \
# 0   0.726120  0.853573  1.670991  1.437951  1.044235 -0.792449 -1.540718
# 1   0.203174 -0.721958 -0.981875  0.127996  1.240127 -0.170082 -0.539187
# 2  -0.321415 -1.130429 -0.142406  1.608815 -0.229063 -0.715391  1.141954
# 3  -1.287231  0.240867 -0.396411 -0.840232 -0.424955 -0.910140 -1.165144
# 4   0.069149  1.291221  1.893785  0.811451  1.729857 -0.345797 -0.253036
# 5   2.918298 -0.109251  1.373149  1.811003 -1.404415  1.957180  1.788120
# 6   1.439125  0.736867 -0.106223 -0.156777 -1.208523  1.484410  1.517528
# 7   0.523129 -0.459369 -0.596892 -1.637596 -1.110577  1.610149 -0.914761
# 8  -0.826377 -0.459369 -0.360046  0.184950  0.064775  0.197451 -0.592841
# 9   1.158507  1.801809  1.636039  1.096224  0.162721  0.000089  0.158307
# 10  1.211577 -0.080075  0.290086  0.241905  0.064775  0.356576  0.605420
# 11  0.817370 -0.838664 -0.724890  0.184950 -0.522901  1.923981  0.301383
# ...

# %%
from scipy.stats import zscore
z=np.abs(zscore(df1))
z
# Out:
# array([[7.26119621e-01, 8.53573157e-01, 1.67099060e+00, 1.43795089e+00,
#         1.04423479e+00, 7.92448936e-01, 1.54071840e+00, 2.47400647e+00,
#         9.18278024e-01, 6.92653250e-01, 5.22846534e-01, 5.21280731e-01,
#         5.45889641e-01, 7.81873120e-01, 1.64763258e+00, 4.29499709e-01,
#         1.36540860e+00],
#        [2.03173544e-01, 7.21957956e-01, 9.81875450e-01, 1.27995893e-01,
#         1.24012676e+00, 1.70082058e-01, 5.39187352e-01, 1.64530995e-01,
#         6.08318968e-01, 1.66398884e-01, 2.56805329e-01, 2.64476711e-01,
#         5.45889641e-01, 2.59566641e-01, 3.09677528e-01, 5.95572421e-01,
#         1.97838300e-01],
#        [3.21414863e-01, 1.13042898e+00, 1.42405539e-01, 1.60881459e+00,
#         2.29063009e-01, 7.15390982e-01, 1.14195404e+00, 9.55178327e-01,
#         1.10079616e-01, 7.07213456e-01, 7.77732720e-01, 6.59943809e-01,
#         2.45115152e+00, 2.34918307e-01, 6.59918696e-01, 1.20887283e+00,
#         3.24325082e-03],
# ...

# %%
print(np.where(z>3))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
df2=df1[(z<3).all(axis=1)]
df2
# Out:
#            R        AB         H        2B        3B        HR        BB  \
# 0   0.726120  0.853573  1.670991  1.437951  1.044235 -0.792449 -1.540718
# 1   0.203174 -0.721958 -0.981875  0.127996  1.240127 -0.170082 -0.539187
# 2  -0.321415 -1.130429 -0.142406  1.608815 -0.229063 -0.715391  1.141954
# 3  -1.287231  0.240867 -0.396411 -0.840232 -0.424955 -0.910140 -1.165144
# 4   0.069149  1.291221  1.893785  0.811451  1.729857 -0.345797 -0.253036
# 5   2.918298 -0.109251  1.373149  1.811003 -1.404415  1.957180  1.788120
# 6   1.439125  0.736867 -0.106223 -0.156777 -1.208523  1.484410  1.517528
# 7   0.523129 -0.459369 -0.596892 -1.637596 -1.110577  1.610149 -0.914761
# 8  -0.826377 -0.459369 -0.360046  0.184950  0.064775  0.197451 -0.592841
# 9   1.158507  1.801809  1.636039  1.096224  0.162721  0.000089  0.158307
# 10  1.211577 -0.080075  0.290086  0.241905  0.064775  0.356576  0.605420
# 11  0.817370 -0.838664 -0.724890  0.184950 -0.522901  1.923981  0.301383
# ...

# %%
df1.shape
# Out:
# (30, 17)

# %%
df2.shape
# Out:
# (30, 17)

# %% [markdown]
# No rows have been removed since there are no outliers.

# %%
x=df2.iloc[:,0:-1]
y=df2.iloc[:,-1]

# %%
x
# Out:
#            R        AB         H        2B        3B        HR        BB  \
# 0   0.726120  0.853573  1.670991  1.437951  1.044235 -0.792449 -1.540718
# 1   0.203174 -0.721958 -0.981875  0.127996  1.240127 -0.170082 -0.539187
# 2  -0.321415 -1.130429 -0.142406  1.608815 -0.229063 -0.715391  1.141954
# 3  -1.287231  0.240867 -0.396411 -0.840232 -0.424955 -0.910140 -1.165144
# 4   0.069149  1.291221  1.893785  0.811451  1.729857 -0.345797 -0.253036
# 5   2.918298 -0.109251  1.373149  1.811003 -1.404415  1.957180  1.788120
# 6   1.439125  0.736867 -0.106223 -0.156777 -1.208523  1.484410  1.517528
# 7   0.523129 -0.459369 -0.596892 -1.637596 -1.110577  1.610149 -0.914761
# 8  -0.826377 -0.459369 -0.360046  0.184950  0.064775  0.197451 -0.592841
# 9   1.158507  1.801809  1.636039  1.096224  0.162721  0.000089  0.158307
# 10  1.211577 -0.080075  0.290086  0.241905  0.064775  0.356576  0.605420
# 11  0.817370 -0.838664 -0.724890  0.184950 -0.522901  1.923981  0.301383
# ...

# %%
y
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 5      93
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: W, dtype: int64

# %%
x.shape
# Out:
# (30, 16)

# %%
y.shape
# Out:
# (30,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
maxAcc=0
maxRS=0
for i in range(1,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=i)
    model=DecisionTreeRegressor()
    model.fit(x_train,y_train)
    pred=model.predict(x_test)
    score=model.score(x_train,y_train)
    if score>maxAcc:
        maxAcc=score
        maxRS=i
print('Best score is', maxAcc,'on random state',maxRS)
# Out:
# Best score is 1.0 on random state 1

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=1)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (20, 16)
# (10, 16)
# (20,)
# (10,)

# %%
lm=LinearRegression()
lm.fit(x_train,y_train)
lm.score(x_train,y_train)
# Out:
# 0.9909122886942268

# %%
pred=lm.predict(x_test)
print('Predicted wins',pred)
print('Actual wins',y_test)
# Out:
# Predicted wins [100.24318584  90.09214488  90.01207735  56.35339648  77.99836656
#   79.42922728  93.66545626  81.5383094   54.25949223  74.27887293]
# Actual wins 17    97
# 21    83
# 10    88
# 19    64
# 14    68
# 20    90
# 26    84
# 3     76
# 24    63
# 22    71
# Name: W, dtype: int64

# %%
lm.coef_
# Out:
# array([ 10.94334374,  -2.11293542,   1.79048578,  -6.08316906,
#          1.49906772,  -4.88477918,  -1.63519311,   0.51516223,
#         -1.30627271,   2.03681232,  14.27769778, -24.78698895,
#          4.68274305,   0.62618931,   4.11289785,   0.91604646])

# %%
lm.intercept_
# Out:
# 81.42901764036823

# %%
print(mean_squared_error(y_test,pred))
print(mean_absolute_error(y_test,pred))
print('Root Mean squared error:', np.sqrt(mean_squared_error(y_test,pred)))
print(r2_score(y_test,pred))
# Out:
# 54.628574327830606
# 6.778629723476627
# Root Mean squared error: 7.391114552476548
# 0.5588777912804375

# %%
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
dtr.score(x_train,y_train)
# Out:
# 1.0

# %%
pred=dtr.predict(x_test)
print('Predicted wins',pred)
print('Actual wins',y_test)
# Out:
# Predicted wins [ 93.  81.  78.  76.  78.  85.  95. 100.  68.  95.]
# Actual wins 17    97
# 21    83
# 10    88
# 19    64
# 14    68
# 20    90
# 26    84
# 3     76
# 24    63
# 22    71
# Name: W, dtype: int64

# %%
print(mean_squared_error(y_test,pred))
print(mean_absolute_error(y_test,pred))
print('Root Mean squared error:', np.sqrt(mean_squared_error(y_test,pred)))
print(r2_score(y_test,pred))
# Out:
# 168.7
# 10.7
# Root Mean squared error: 12.988456413292536
# -0.3622416020671837

# %%
svr=SVR()
svr.fit(x_train,y_train)
svr.score(x_train,y_train)
# Out:
# 0.17470534440487429

# %%
pred=svr.predict(x_test)
print('Predicted wins',pred)
print('Actual wins',y_test)
# Out:
# Predicted wins [81.46403285 81.77854399 79.80440599 79.3837512  79.76734143 81.7178402
#  80.74598012 79.50486931 78.80057703 80.18389665]
# Actual wins 17    97
# 21    83
# 10    88
# 19    64
# 14    68
# 20    90
# 26    84
# 3     76
# 24    63
# 22    71
# Name: W, dtype: int64

# %%
print(mean_squared_error(y_test,pred))
print(mean_absolute_error(y_test,pred))
print('Root Mean squared error:', np.sqrt(mean_squared_error(y_test,pred)))
print(r2_score(y_test,pred))
# Out:
# 111.06252337750838
# 9.212963246471514
# Root Mean squared error: 10.538620563314176
# 0.10317729830823319

# %%
knn=KNeighborsRegressor()
knn.fit(x_train,y_train)
knn.score(x_train,y_train)
# Out:
# 0.65497475092125

# %%
pred=knn.predict(x_test)
print('Predicted wins',pred)
print('Actual wins',y_test)
# Out:
# Predicted wins [86.8 84.  78.4 76.  75.8 86.2 83.2 77.2 72.  75.4]
# Actual wins 17    97
# 21    83
# 10    88
# 19    64
# 14    68
# 20    90
# 26    84
# 3     76
# 24    63
# 22    71
# Name: W, dtype: int64

# %%
print(mean_squared_error(y_test,pred))
print(mean_absolute_error(y_test,pred))
print('Root Mean squared error:', np.sqrt(mean_squared_error(y_test,pred)))
print(r2_score(y_test,pred))
# Out:
# 51.891999999999996
# 5.9799999999999995
# Root Mean squared error: 7.203610206000877
# 0.5809754521963824

# %%
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
# Out:
# 0.933298485055275

# %%
pred=rf.predict(x_test)
print('Predicted wins',pred)
print('Actual wins',y_test)
# Out:
# Predicted wins [90.17 85.65 74.86 73.3  74.97 89.18 90.28 86.18 71.02 85.5 ]
# Actual wins 17    97
# 21    83
# 10    88
# 19    64
# 14    68
# 20    90
# 26    84
# 3     76
# 24    63
# 22    71
# Name: W, dtype: int64

# %%
print(mean_squared_error(y_test,pred))
print(mean_absolute_error(y_test,pred))
print('Root Mean squared error:', np.sqrt(mean_squared_error(y_test,pred)))
print(r2_score(y_test,pred))
# Out:
# 77.97155000000001
# 7.869
# Root Mean squared error: 8.830150055350137
# 0.3703847706718345

# %% [markdown]
# These accuracy scores can be because of overfitting. Lets check with cross validation.

# %% [markdown]
# # Cross Validation

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(lm,x,y,cv=5)
print(score)
print(score.mean())
# Out:
# [ 0.78849858 -4.25855703  0.63076924  0.70260613  0.58331063]
# -0.31067448921689705

# %%
score=cross_val_score(dtr,x,y,cv=5)
print(score)
print(score.mean())
# Out:
# [-0.64920071 -8.60687023 -0.91355674  0.37080063  0.37514793]
# -1.8847358245678105

# %%
score=cross_val_score(svr,x,y,cv=5)
print(score)
print(score.mean())
# Out:
# [-0.10201215 -0.9194809  -0.26876943 -0.59229582 -0.0093306 ]
# -0.3783777813273047

# %%
score=cross_val_score(knn,x,y,cv=5)
print(score)
print(score.mean())
# Out:
# [ 0.3164476  -2.4621374   0.30792079  0.36982104  0.72293491]
# -0.14900261260403055

# %%
score=cross_val_score(rf,x,y,cv=5)
print(score)
print(score.mean())
# Out:
# [ 0.1925881  -4.53423511  0.24849863  0.40038053  0.79343828]
# -0.579865913633473

# %% [markdown]
# # Hyper Parameter Tuning

# %% [markdown]
# We use this technique to improve the accuracy of the best model that we have choosen.

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters={'n_neighbors':[3,5,7,9,10,13],
            'weights':['uniform','distance'],
            'algorithm':['auto','ball_tree','kd_tree','brute'],
            'leaf_size':[15,17,21,25,30]}
gs=GridSearchCV(KNeighborsRegressor(),parameters,cv=5)
gs.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsRegressor(),
#              param_grid={'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
#                          'leaf_size': [15, 17, 21, 25, 30],
#                          'n_neighbors': [3, 5, 7, 9, 10, 13],
#                          'weights': ['uniform', 'distance']})

# %%
print(gs.best_params_)
# Out:
# {'algorithm': 'brute', 'leaf_size': 15, 'n_neighbors': 3, 'weights': 'distance'}

# %%
knnmodel=KNeighborsRegressor(algorithm='brute',leaf_size=15,n_neighbors=3,weights='distance')
knnmodel.fit(x_train,y_train)
score=knn.score(x_train,y_train)
print(score*100)
# Out:
# 65.497475092125

# %% [markdown]
# # Saving the model

# %%
import joblib
joblib.dump(knnmodel,'knnmodel.obj')
# Out:
# ['knnmodel.obj']
